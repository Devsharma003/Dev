# %% [markdown]
# <a href="https://colab.research.google.com/github/Devsharma003/Dev/blob/main/randomforest_company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d5359469-29c1-408d-9ee1-bbe90c6421fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5359469-29c1-408d-9ee1-bbe90c6421fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Company_Data (1).csv')

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data.loc[data.Sales >=8.5,'sales']= 'high'
data.loc[data.Sales <8.5,'sales']= 'low'

# %%
data.drop('Sales',1,inplace=True)

# %%
data.isnull().sum()
# Out:
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# sales          0
# dtype: int64

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['US']= label_encoder.fit_transform(data['US'])
data['US'].unique()
# Out:
# array([1, 0])

# %%
label_encoder = preprocessing.LabelEncoder()
data['Urban']= label_encoder.fit_transform(data['Urban'])

# %%
label_encoder = preprocessing.LabelEncoder()
data['ShelveLoc']= label_encoder.fit_transform(data['ShelveLoc'])

# %%
colnames = list(data.columns)
predictors = colnames[0:10]
target = colnames[10]

# %%
predictors
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'ShelveLoc',
#  'Age',
#  'Education',
#  'Urban',
#  'US']

# %%
target
# Out:
# 'sales'

# %%
label_encoder = preprocessing.LabelEncoder()
data['sales']= label_encoder.fit_transform(data['sales'])

# %%
X = data[predictors]
Y = data[target]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=2,oob_score=True,n_estimators=1000,criterion="entropy")

# %%
rf.fit(X,Y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=1000, n_jobs=2,
#                        oob_score=True)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=1892814334),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=1721335690),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=33135511),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=892467068),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=97993014),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=1126517885),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=483109635),
#  DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                         random_state=545991169),
# ...

# %%
rf.classes_
# Out:
# array([0, 1])

# %%
rf.n_classes_
# Out:
# 2

# %%
rf.n_outputs_
# Out:
# 1

# %%
data['rf_pred'] = rf.predict(X)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(data['sales'],data['rf_pred'])
# Out:
# array([[143,   0],
#        [  0, 257]])

# %% [markdown]
# # Now will try with 500 decision trees

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=2,oob_score=True,n_estimators=500,criterion="entropy")

# %%
rf.fit(X,Y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=500, n_jobs=2,
#                        oob_score=True)

# %%
data['rf_pred2'] = rf.predict(X)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(data['sales'],data['rf_pred2'])
# Out:
# array([[143,   0],
#        [  0, 257]])
