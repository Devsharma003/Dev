# %% [markdown]
# <a href="https://colab.research.google.com/github/Devsharma003/Dev/blob/main/text_minning_%5Belon_musk%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install spicy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import string
import spacy
import seaborn as sns
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8eb769c0-df61-4c9a-8d03-96e9b0b0250b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8eb769c0-df61-4c9a-8d03-96e9b0b0250b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
elon=pd.read_csv("Elon_musk.csv",encoding='unicode_escape')

# %%
elon
# Out:
#       Unnamed: 0                                               Text
# 0              1                             @kunalb11 Im an alien
# 1              2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2              3                @joerogan @Spotify Great interview!
# 3              4                    @gtera27 Doge is underestimated
# 4              5  @teslacn Congratulations Tesla China for amazi...
# ...          ...                                                ...
# 1994        1995  @flcnhvy True, it sounds so surreal, but the n...
# 1995        1996  @PPathole Make sure to read ur terms &amp; con...
# 1996        1997                @TeslaGong @PPathole Samwise Gamgee
# 1997        1998  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998        1999                          Progress update August 28
#
# [1999 rows x 2 columns]

# %% [markdown]
# ### stripping the reviews of spaces before and after the text

# %%
elon_musk = [x.strip() for x in elon.Text]
elon_musk = [x for x in elon_musk if x]
elon_musk[0:10]
# Out:
# ['@kunalb11 I\x92m an alien',
#  '@ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated',
#  '@teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!',
#  'Happy New Year of the Ox! https://t.co/9WFKMYu2oj',
#  'Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM',
#  '@OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)',
#  '@flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.',
#  'The most entertaining outcome is the most likely']

# %%
import spacy

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Getting sentences

# %%
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(elon_musk))
sentences[0:10]
# Out:
# ['@kunalb11 I\x92m an alien @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level.',
#  'Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated @teslacn Congratulations Tesla China for amazing execution last year.',
#  'Now on to the next for even more!!',
#  'Happy New Year of the Ox!',
#  'https://t.co/9WFKMYu2oj Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all.',
#  'https://t.co/zGxJFDzzrM @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :) @flcnhvy @anonyx10 Indeed!',
#  'Tweets definitely do not represent real-world time allocation.',
# ...

# %% [markdown]
# ## Making the data into a dataframe

# %%
sent_df = pd.DataFrame(sentences, columns=['sentence'])
sent_df
# Out:
#                                               sentence
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...
# 1                                   Have you tried it?
# 2                  @joerogan @Spotify Great interview!
# 3    @gtera27 Doge is underestimated @teslacn Congr...
# 4                   Now on to the next for even more!!
# ..                                                 ...
# 922  @kenyanwalstreet Not actually a payout, just a...
# 923  It may never pay out, as the stock cant b
#  ht...
# 924                                    Details Aug 28.
# 925  AI symbiosis while u wait @vistacruiser7 @flcn...
# 926  @TeslaGong @PPathole Samwise Gamgee @PPathole ...
#
# [927 rows x 1 columns]

# %% [markdown]
# ## Getting the negative words affinity values

# %% [markdown]
# ## putting affinity to be -1 for all the words

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-aa10a5e9-6bab-4792-aa5d-91e66793bd2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa10a5e9-6bab-4792-aa5d-91e66793bd2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
afinn_n =pd.read_csv("negative-words.txt",sep=';',encoding='latin-1')
afinn_n.shape
# Out:
# (4816, 79)

# %%
afinn_n
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN
# 1           NaN                          Opinion Lexicon: Negative
# 2           NaN                                                NaN
# 3           NaN   This file contains a list of NEGATIVE opinion...
# 4           NaN                                                NaN
# ...         ...                                                ...
# 4811       zaps                                                NaN
# 4812     zealot                                                NaN
# 4813    zealous                                                NaN
# 4814  zealously                                                NaN
# 4815     zombie                                                NaN
#
#       Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
afinn_n=afinn_n.iloc[:,0]

# %%
afinn_n
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 4811         zaps
# 4812       zealot
# 4813      zealous
# 4814    zealously
# 4815       zombie
# Name: Unnamed: 0, Length: 4816, dtype: object

# %%
afinn_n.dropna(inplace=True)

# %%
afinn_n
# Out:
# 33         2-faced
# 34         2-faces
# 35        abnormal
# 36         abolish
# 37      abominable
#            ...
# 4811          zaps
# 4812        zealot
# 4813       zealous
# 4814     zealously
# 4815        zombie
# Name: Unnamed: 0, Length: 4783, dtype: object

# %%
afinn_n=afinn_n.reset_index()

# %%
afinn_n
# Out:
#       index  Unnamed: 0
# 0        33     2-faced
# 1        34     2-faces
# 2        35    abnormal
# 3        36     abolish
# 4        37  abominable
# ...     ...         ...
# 4778   4811        zaps
# 4779   4812      zealot
# 4780   4813     zealous
# 4781   4814   zealously
# 4782   4815      zombie
#
# [4783 rows x 2 columns]

# %%
afinn_n['Value']=-1

# %%
afinn_n
# Out:
#       index  Unnamed: 0  Value
# 0        33     2-faced     -1
# 1        34     2-faces     -1
# 2        35    abnormal     -1
# 3        36     abolish     -1
# 4        37  abominable     -1
# ...     ...         ...    ...
# 4778   4811        zaps     -1
# 4779   4812      zealot     -1
# 4780   4813     zealous     -1
# 4781   4814   zealously     -1
# 4782   4815      zombie     -1
#
# [4783 rows x 3 columns]

# %%
afinn_n.drop(['index'],axis=1,inplace=True)

# %%
afinn_n
# Out:
#       Unnamed: 0  Value
# 0        2-faced     -1
# 1        2-faces     -1
# 2       abnormal     -1
# 3        abolish     -1
# 4     abominable     -1
# ...          ...    ...
# 4778        zaps     -1
# 4779      zealot     -1
# 4780     zealous     -1
# 4781   zealously     -1
# 4782      zombie     -1
#
# [4783 rows x 2 columns]

# %%
afinn_n.columns=['words','value']

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b5ca089d-488e-4c71-98fe-0699afbd40e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5ca089d-488e-4c71-98fe-0699afbd40e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
afinn_p=pd.read_csv("positive-words.txt",sep=';',encoding='latin-1')
afinn_p.shape
# Out:
# (2039, 77)

# %% [markdown]
# ## Getting the positive words affinity values

# %% [markdown]
# ## putting affinity to be -1 for all the words

# %%
afinn_p=afinn_p.iloc[:,0]
afinn_p.dropna(inplace=True)
afinn_p=afinn_p.reset_index()
afinn_p['value']=1
afinn_p.drop(['index'],axis=1,inplace=True)
afinn_p.columns=['words','value']
afinn_p
# Out:
#           words  value
# 0            a+      1
# 1        abound      1
# 2       abounds      1
# 3     abundance      1
# 4      abundant      1
# ...         ...    ...
# 2001   youthful      1
# 2002       zeal      1
# 2003     zenith      1
# 2004       zest      1
# 2005      zippy      1
#
# [2006 rows x 2 columns]

# %%
afinn_n
# Out:
#            words  value
# 0        2-faced     -1
# 1        2-faces     -1
# 2       abnormal     -1
# 3        abolish     -1
# 4     abominable     -1
# ...          ...    ...
# 4778        zaps     -1
# 4779      zealot     -1
# 4780     zealous     -1
# 4781   zealously     -1
# 4782      zombie     -1
#
# [4783 rows x 2 columns]

# %%
afinn_p
# Out:
#           words  value
# 0            a+      1
# 1        abound      1
# 2       abounds      1
# 3     abundance      1
# 4      abundant      1
# ...         ...    ...
# 2001   youthful      1
# 2002       zeal      1
# 2003     zenith      1
# 2004       zest      1
# 2005      zippy      1
#
# [2006 rows x 2 columns]

# %% [markdown]
# ### concatinating the dataframes to get an affinity dataframe

# %%
afinn=pd.concat([afinn_n,afinn_p],ignore_index=True)

# %%
afinn
# Out:
#            words  value
# 0        2-faced     -1
# 1        2-faces     -1
# 2       abnormal     -1
# 3        abolish     -1
# 4     abominable     -1
# ...          ...    ...
# 6784    youthful      1
# 6785        zeal      1
# 6786      zenith      1
# 6787        zest      1
# 6788       zippy      1
#
# [6789 rows x 2 columns]

# %%
affinity_scores = afinn.set_index('words')['value'].to_dict()

# %%
affinity_scores
# Out:
# {'2-faced': -1,
#  '2-faces': -1,
#  'abnormal': -1,
#  'abolish': -1,
#  'abominable': -1,
#  'abominably': -1,
#  'abominate': -1,
#  'abomination': -1,
#  'abort': -1,
#  'aborted': -1,
#  'aborts': -1,
#  'abrade': -1,
#  'abrasive': -1,
#  'abrupt': -1,
#  'abruptly': -1,
#  'abscond': -1,
#  'absence': -1,
#  'absent-minded': -1,
#  'absentee': -1,
#  'absurd': -1,
#  'absurdity': -1,
#  'absurdly': -1,
#  'absurdness': -1,
#  'abuse': -1,
#  'abused': -1,
#  'abuses': -1,
#  'abusive': -1,
#  'abysmal': -1,
#  'abysmally': -1,
#  'abyss': -1,
#  'accidental': -1,
#  'accost': -1,
#  'accursed': -1,
#  'accusation': -1,
#  'accusations': -1,
#  'accuse': -1,
#  'accuses': -1,
#  'accusing': -1,
#  'accusingly': -1,
#  'acerbate': -1,
#  'acerbic': -1,
#  'acerbically': -1,
#  'ache': -1,
#  'ached': -1,
#  'aches': -1,
#  'achey': -1,
#  'aching': -1,
#  'acrid': -1,
#  'acridly': -1,
#  'acridness': -1,
#  'acrimonious': -1,
#  'acrimoniously': -1,
#  'acrimony': -1,
# ...

# %% [markdown]
# ## Defining a function to calculate sentiment

# %%
# !python -m spacy download en_core_web_md
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 14:27:31.696652: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 14:27:31.696814: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
nlp = spacy.load('en_core_web_md')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %% [markdown]
# ## Calculating sentiment

# %%
sent_df['sentiment_value'] = sent_df['sentence'].apply(calculate_sentiment)

# %%
sent_df
# Out:
#                                               sentence  sentiment_value
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                1
# 3    @gtera27 Doge is underestimated @teslacn Congr...                0
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 922  @kenyanwalstreet Not actually a payout, just a...                0
# 923  It may never pay out, as the stock cant b
#  ht...               -1
# 924                                    Details Aug 28.                0
# 925  AI symbiosis while u wait @vistacruiser7 @flcn...                0
# 926  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
# [927 rows x 2 columns]

# %% [markdown]
# ## Data with sentiment value greater than 5

# %%
sent_df[sent_df.sentiment_value>5]
# Out:
#                                               sentence  sentiment_value
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...                6
# 105  @Erdayastronaut @SpaceX Was also thinking that...                6
# 655  Its not useful for predicting the future, nor...                9

# %% [markdown]
# ## Finding with sentiment value greater than 5

# %%
sent_df['word_count'] = sent_df['sentence'].str.split().apply(len)
sent_df.head(10)
# Out:
#                                             sentence  sentiment_value  \
# 0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                 Have you tried it?                0
# 2                @joerogan @Spotify Great interview!                1
# 3  @gtera27 Doge is underestimated @teslacn Congr...                0
# 4                 Now on to the next for even more!!                0
# 5                          Happy New Year of the Ox!                0
# 6  https://t.co/9WFKMYu2oj Frodo was the underdog...               -1
# 7  https://t.co/zGxJFDzzrM @OwenSparks_ @flcnhvy ...                1
# 8  Tweets definitely do not represent real-world ...                0
# 9  The most entertaining outcome is the most like...                0
#
#    word_count
# 0          13
# 1           4
# 2           4
# 3          13
# 4           8
# 5           6
# 6          14
# 7          10
# 8           8
# 9         109

# %%
sent_df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                               sentence  sentiment_value  \
# 776  RT @RealLifeStarman: We are going to go to th...                4
# 301  It was designed from the beginning with human ...                5
# 123  It isnt enough to be safer than human drivers...                5
# 373  @Chad_Hurley @realDonaldTrump @kanyewest Stop ...                5
# 572  @WholeMarsBlog Haha true @oneandonlyheady Mayb...                5
# 722  We just havent observed the
#  https://t.co/mez...                5
# 583  T
#  https://t.co/DyNlT5EKGk @Model3Owners Fine,...                5
# 105  @Erdayastronaut @SpaceX Was also thinking that...                6
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...                6
# 655  Its not useful for predicting the future, nor...                9
#
#      word_count
# 776          93
# 301          64
# 123          51
# 373          65
# 572          68
# 722          72
# 583          37
# 105          94
# ...

# %%
sent_df['sentiment_value'].describe()
# Out:
# count    927.000000
# mean       0.455232
# std        1.240032
# min       -5.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        9.000000
# Name: sentiment_value, dtype: float64

# %%
sent_df[sent_df['sentiment_value']<=0].head()
# Out:
#                                             sentence  sentiment_value  \
# 0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                 Have you tried it?                0
# 3  @gtera27 Doge is underestimated @teslacn Congr...                0
# 4                 Now on to the next for even more!!                0
# 5                          Happy New Year of the Ox!                0
#
#    word_count
# 0          13
# 1           4
# 3          13
# 4           8
# 5           6

# %% [markdown]
# ## plotting the sentiment value

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(y=sent_df['sentiment_value'],x=sent_df.index)
# Out:
# <Axes: ylabel='sentiment_value'>

# %% [markdown]
# ### plotting the scatterplot of sentiment value vs word count

# %%
sent_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8),
                     title='Sentence sentiment value to sentence word count')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: title={'center': 'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>
