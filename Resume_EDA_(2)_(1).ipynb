# %% [markdown]
# <a href="https://colab.research.google.com/github/Devsharma003/Dev/blob/main/Resume_EDA_(2)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-doc
# !python3 -m pip install docx2txt
# !pip install textract
# !sudo apt-get install antiword
# !pip install python-docx
# !pip install wordcloud
# !pip install xgboost
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-doc
#   Downloading python_doc-2020.10.1-py2.py3-none-any.whl (39.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.10/dist-packages (from python-doc) (8.1.3)
# Collecting blurb (from python-doc)
#   Downloading blurb-1.1.0-py3-none-any.whl (22 kB)
# Collecting python-docs-theme (from python-doc)
#   Downloading python_docs_theme-2023.5-py3-none-any.whl (17 kB)
# Collecting sphinx==2.4.4 (from python-doc)
#   Downloading Sphinx-2.4.4-py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (2.14.0)
# Requirement already satisfied: docutils>=0.12 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (0.16)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (2.2.0)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx==2.4.4->python-doc) (23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx==2.4.4->python-doc) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx==2.4.4->python-doc) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx==2.4.4->python-doc) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx==2.4.4->python-doc) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx==2.4.4->python-doc) (3.4)
# Installing collected packages: python-docs-theme, blurb, sphinx, python-doc
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 3.5.4
#     Uninstalling Sphinx-3.5.4:
#       Successfully uninstalled Sphinx-3.5.4
# Successfully installed blurb-1.1.0 python-doc-2020.10.1 python-docs-theme-2023.5 sphinx-2.4.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3957 sha256=62035fd1a2b31752176d99488554419cfdd062581decb943c17775419b327f85
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textract
#   Downloading textract-1.6.5-py3-none-any.whl (23 kB)
# Collecting argcomplete~=1.10.0 (from textract)
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0 (from textract)
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 11.1 MB/s eta 0:00:00
# Collecting chardet==3.* (from textract)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: docx2txt~=0.8 in /usr/local/lib/python3.10/dist-packages (from textract) (0.8)
# Collecting extract-msg<=0.29.* (from textract)
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 8.8 MB/s eta 0:00:00
# Collecting pdfminer.six==20191110 (from textract)
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.5 MB/s eta 0:00:00
# Collecting python-pptx~=0.6.18 (from textract)
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 138.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting six~=1.12.0 (from textract)
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1 (from textract)
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 13.4 MB/s eta 0:00:00
# Collecting xlrd~=1.2.0 (from textract)
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 13.0 MB/s eta 0:00:00
# Collecting pycryptodome (from pdfminer.six==20191110->textract)
#   Downloading pycryptodome-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 106.9 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.4.1)
# Collecting imapclient==2.1.0 (from extract-msg<=0.29.*->textract)
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 10.0 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from extract-msg<=0.29.*->textract)
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.0.1)
# Collecting compressed-rtf>=1.0.6 (from extract-msg<=0.29.*->textract)
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic>=1.1.1 (from extract-msg<=0.29.*->textract)
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx~=0.6.18->textract)
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 17.8 MB/s eta 0:00:00
# Building wheels for collected packages: python-pptx, compressed-rtf, olefile
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470935 sha256=30ca360cd3ebd1cc4f83d54aa2f78ad658c672f0143ae08da85a251e37190177
#   Stored in directory: /root/.cache/pip/wheels/ea/dd/74/01b3ec7256a0800b99384e9a0f7620e358afc3a51a59bf9b49
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6185 sha256=dd8cdbc967d5c020f85c9bf7c0892fac3d1801b732177578845307c34508ca11
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=66fec1e6a6e888da3484c4544954a4742330ae85a70a5e6a3260141c8e408a5b
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
# Successfully built python-pptx compressed-rtf olefile
# Installing collected packages: SpeechRecognition, ebcdic, compressed-rtf, chardet, argcomplete, XlsxWriter, xlrd, six, pycryptodome, olefile, beautifulsoup4, python-pptx, pdfminer.six, imapclient, extract-msg, textract
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.21 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed SpeechRecognition-3.8.1 XlsxWriter-3.1.2 argcomplete-1.10.3 beautifulsoup4-4.8.2 chardet-3.0.4 compressed-rtf-1.0.6 ebcdic-1.1.1 extract-msg-0.28.7 imapclient-2.1.0 olefile-0.46 pdfminer.six-20191110 pycryptodome-3.18.0 python-pptx-0.6.21 six-1.12.0 textract-1.6.5 xlrd-1.2.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   antiword
# 0 upgraded, 1 newly installed, 0 to remove and 13 not upgraded.
# Need to get 118 kB of archives.
# After this operation, 603 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 antiword amd64 0.37-16 [118 kB]
# Fetched 118 kB in 0s (1,620 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package antiword.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../antiword_0.37-16_amd64.deb ...
# Unpacking antiword (0.37-16) ...
# Setting up antiword (0.37-16) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.2)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184491 sha256=84780a520e769f56e7eea04f29cbaeb810dfa95db9495e7bfeac628012421a5f
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.12.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (1.7.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.10.1)
# 2023-06-27 07:24:33.818448: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 07:24:34.712163: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 80.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os,re
import docx2txt
import textract
import pandas as pd
import numpy as np
from docx import Document
import nltk
nltk.download('punkt')
import matplotlib.pyplot as plt
from wordcloud import WordCloud
nltk.download("stopwords")
nltk.download("all")
import xgboost as xgb
from nltk.stem import WordNetLemmatizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report

# %% [markdown]
# # **Loading The Data SET**

# %%
path= '/content/drive/MyDrive/Project_Resume/Resumes'

for(root,dirs,file) in os.walk(path):
    for f in file:
        if '.docx' and '.doc' in f:
            print(f)

# %%
file_1 = []
category_1 = []

directory = "/content/drive/MyDrive/Project_Resume/Resumes"
for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        os.path.join(directory, i)
        file_1.append((textract.process(os.path.join(directory, i))).decode('utf-8'))
        category_1.append('React JS Developer Resume')

# %%
file_1, category_1

# %%
file2 = []
category2=[]

directory = "/content/drive/MyDrive/Project_Resume/Resumes/Peoplesoft resumes"
for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        os.path.join(directory, i)
        file2.append((textract.process(os.path.join(directory, i))).decode('utf-8'))
        category2.append('Peoplesoft Resume')

# %%
file2, category2

# %%
file3 =[]
category3 = []

directory = "/content/drive/MyDrive/Project_Resume/Resumes/SQL Developer Lightning insight"
for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        os.path.join(directory, i)
        file3.append((textract.process(os.path.join(directory, i))).decode('utf-8'))
        category3.append('SQL Developer Lightning insight')

# %%
file3, category3

# %%
file4=[]
category4=[]

directory = "/content/drive/MyDrive/Project_Resume/Resumes/workday resumes"
for i in os.listdir(directory):
    if i.endswith('.docx') or i.endswith('.doc') or i.endswith('.pdf'):
        os.path.join(directory, i)
        file4.append((textract.process(os.path.join(directory, i))).decode('utf-8'))
        category4.append('Workday Resumes')

# %%
file4,category4

# %%
data1 = pd.DataFrame(data= file_1, columns=['Resumes'])
data1['category_1'] = category_1
data1
# Out:
#                                               Resumes  \
# 0   Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 1   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 2   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 3   Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 4   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 5   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 6   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 7   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 8   \n                              CURRICULUM VIT...
# 9   HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 10  \nMaryala Vinay Reddy\n\nProfessional Summary:...
# 11  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 12  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 13  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 14  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 15  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 16   \n\n \n\nName: M. Prabakaran \nTitle: UI Deve...
# 17  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 18  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 19  \n [pic]\n\nPROFILE\n\n Searching for the oppo...
# 20  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22  Name: Ravali P \n\n\n\n                       ...
# 23  Ui-Developer/ React JS Developer \n\nNAME: KRI...
#
#                    category_1
# 0   React JS Developer Resume
# 1   React JS Developer Resume
# 2   React JS Developer Resume
# 3   React JS Developer Resume
# 4   React JS Developer Resume
# 5   React JS Developer Resume
# 6   React JS Developer Resume
# 7   React JS Developer Resume
# 8   React JS Developer Resume
# 9   React JS Developer Resume
# 10  React JS Developer Resume
# 11  React JS Developer Resume
# 12  React JS Developer Resume
# 13  React JS Developer Resume
# 14  React JS Developer Resume
# 15  React JS Developer Resume
# 16  React JS Developer Resume
# 17  React JS Developer Resume
# 18  React JS Developer Resume
# 19  React JS Developer Resume
# 20  React JS Developer Resume
# 21  React JS Developer Resume
# 22  React JS Developer Resume
# 23  React JS Developer Resume

# %%
data2 = pd.DataFrame(data= file2, columns=['Resumes'])
data2['category2'] = category2
data2
# Out:
#                                               Resumes          category2
# 0   PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft Resume
# 1   \n                          PEOPLESOFT Adminis...  Peoplesoft Resume
# 2   Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft Resume
# 3   \nArun Venu\n\n\n  EXPERIENCE SUMMARY\n\n\n   ...  Peoplesoft Resume
# 4   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft Resume
# 5   \nRahul Ahuja\n-------------------------------...  Peoplesoft Resume
# 6   \n                        PeopleSoft Admin/Peo...  Peoplesoft Resume
# 7   \n                      PeopleSoft Database Ad...  Peoplesoft Resume
# 8   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft Resume
# 9   Classification: Internal\n\nClassification: In...  Peoplesoft Resume
# 10  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft Resume
# 11  \n|Personal Details                           ...  Peoplesoft Resume
# 12  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  Peoplesoft Resume
# 13  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  Peoplesoft Resume
# 14  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...  Peoplesoft Resume
# 15  \nPriyanka Ramadoss\n\n61/46, MountPleasant,\n...  Peoplesoft Resume
# 16  \n\nR Ahmed\n                          PeopleS...  Peoplesoft Resume
# 17  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...  Peoplesoft Resume
# 18  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft Resume
# 19  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft Resume

# %%
data3 = pd.DataFrame(data= file3, columns=['Resumes'])
data3['category3'] = category3
data3
# Out:
#                                               Resumes  \
# 0   SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 1   ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 2   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 3   Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 4   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 5   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 6   Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 7   \n\n\n\n\n “ Hyderabad\nNazeer Basha\n SQL and...
# 8   BUDDHA VAMSI                                  ...
# 9   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 10  KAMBALLA PRADEEP                              ...
# 11  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 12  \n\nCareer objective\n\n\nA rewarding opportun...
# 13  \n                                       SQL S...
#
#                           category3
# 0   SQL Developer Lightning insight
# 1   SQL Developer Lightning insight
# 2   SQL Developer Lightning insight
# 3   SQL Developer Lightning insight
# 4   SQL Developer Lightning insight
# 5   SQL Developer Lightning insight
# 6   SQL Developer Lightning insight
# 7   SQL Developer Lightning insight
# 8   SQL Developer Lightning insight
# 9   SQL Developer Lightning insight
# 10  SQL Developer Lightning insight
# 11  SQL Developer Lightning insight
# 12  SQL Developer Lightning insight
# 13  SQL Developer Lightning insight

# %%
data4= pd.DataFrame(data= file4, columns=['Resumes'])
data4['category4'] = category4
data4
# Out:
#                                               Resumes        category4
# 0   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...  Workday Resumes
# 1   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...  Workday Resumes
# 2   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...  Workday Resumes
# 3   \nHIMA.MENDU\n\n\n\nCareer Objective\nTo conti...  Workday Resumes
# 4   \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...  Workday Resumes
# 5   Srikanth (WORKDAY hCM Consultant)\t           ...  Workday Resumes
# 6   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...  Workday Resumes
# 7   Vinay kumar .v\nWorkday Functional Consultant\...  Workday Resumes
# 8   Workday HCM  Techno functional Consultant     ...  Workday Resumes
# 9   \nShireesh                                    ...  Workday Resumes
# 10  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...  Workday Resumes
# 11  \n                               Hari Krishna ...  Workday Resumes
# 12  G Himaja\n\n                                  ...  Workday Resumes
# 13  \n      Workday Integration Consultant\n\nName...  Workday Resumes
# 14  \nName  : Naresh Babu Cherukuri\n\n\nObjective...  Workday Resumes
# 15  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...  Workday Resumes
# 16  \n[pic]                                   Name...  Workday Resumes
# 17  \nHarikrishna Akula\n\n\n\n Summary:\n    ❖ 5....  Workday Resumes
# 18  Mooraboyina Guravaiah\n\nWorkday Integration S...  Workday Resumes
# 19  \nVenkateswarlu.B                             ...  Workday Resumes
# 20  \n\n                             Madeeswar A\n...  Workday Resumes

# %%
data= data1.append([data2,data3,data4],ignore_index=True)
data
# Out:
# <ipython-input-17-1a711a5f7b18>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data= data1.append([data2,data3,data4],ignore_index=True)
#                                               Resumes  \
# 0   Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 1   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 2   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 3   Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 4   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# ..                                                ...
# 74  \n[pic]                                   Name...
# 75  \nHarikrishna Akula\n\n\n\n Summary:\n    ❖ 5....
# 76  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 77  \nVenkateswarlu.B                             ...
# 78  \n\n                             Madeeswar A\n...
#
#                    category_1 category2 category3        category4
# 0   React JS Developer Resume       NaN       NaN              NaN
# 1   React JS Developer Resume       NaN       NaN              NaN
# 2   React JS Developer Resume       NaN       NaN              NaN
# 3   React JS Developer Resume       NaN       NaN              NaN
# 4   React JS Developer Resume       NaN       NaN              NaN
# ..                        ...       ...       ...              ...
# 74                        NaN       NaN       NaN  Workday Resumes
# 75                        NaN       NaN       NaN  Workday Resumes
# 76                        NaN       NaN       NaN  Workday Resumes
# 77                        NaN       NaN       NaN  Workday Resumes
# 78                        NaN       NaN       NaN  Workday Resumes
#
# [79 rows x 5 columns]

# %%
data['Category'] = category_1 + category2 + category3 + category4

# %%
data
# Out:
#                                               Resumes  \
# 0   Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 1   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 2   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 3   Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 4   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# ..                                                ...
# 74  \n[pic]                                   Name...
# 75  \nHarikrishna Akula\n\n\n\n Summary:\n    ❖ 5....
# 76  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 77  \nVenkateswarlu.B                             ...
# 78  \n\n                             Madeeswar A\n...
#
#                    category_1 category2 category3        category4  \
# 0   React JS Developer Resume       NaN       NaN              NaN
# 1   React JS Developer Resume       NaN       NaN              NaN
# 2   React JS Developer Resume       NaN       NaN              NaN
# 3   React JS Developer Resume       NaN       NaN              NaN
# 4   React JS Developer Resume       NaN       NaN              NaN
# ..                        ...       ...       ...              ...
# 74                        NaN       NaN       NaN  Workday Resumes
# 75                        NaN       NaN       NaN  Workday Resumes
# 76                        NaN       NaN       NaN  Workday Resumes
# 77                        NaN       NaN       NaN  Workday Resumes
# 78                        NaN       NaN       NaN  Workday Resumes
#
#                      Category
# 0   React JS Developer Resume
# 1   React JS Developer Resume
# 2   React JS Developer Resume
# 3   React JS Developer Resume
# 4   React JS Developer Resume
# ..                        ...
# 74            Workday Resumes
# 75            Workday Resumes
# 76            Workday Resumes
# 77            Workday Resumes
# 78            Workday Resumes
#
# [79 rows x 6 columns]

# %% [markdown]
# # **EDA**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Resumes     79 non-null     object
#  1   category_1  24 non-null     object
#  2   category2   20 non-null     object
#  3   category3   14 non-null     object
#  4   category4   21 non-null     object
#  5   Category    79 non-null     object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %%
data.isnull().sum()
# Out:
# Resumes        0
# category_1    55
# category2     59
# category3     65
# category4     58
# Category       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Resumes       object
# category_1    object
# category2     object
# category3     object
# category4     object
# Category      object
# dtype: object

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation,remove URLs and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = re.sub('RT|cc', ' ', text)
    text = re.sub('http\S+\s*', ' ',text)
    text = re.sub('#\S+', '', text)
    text =  re.sub('\s+', ' ', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub("[0-9" "]+"," ",text)
    text = re.sub('[‘’“”…]', '', text)
    text = nltk.tokenize.word_tokenize(text)         # tokenization
    text = [w for w in text if not w in nltk.corpus.stopwords.words('english')]     # remove stop words
    return ' '.join(text)

clean = lambda x: clean_text(x)

# %%
data['Resumes'] = data.Resumes.apply(clean)

# %%
data
# Out:
#                                               Resumes  \
# 0   ui developer react js developer name krishna p...
# 1   md khizaruddin rauf experience currently worki...
# 2   pragnya pattnaik expertise around years experi...
# 3   venkatalakshmi pedireddy software developer ex...
# 4   kotani durga prasad objective aspirant positio...
# ..                                                ...
# 74  pic name j sumanth royal professional summary ...
# 75  harikrishna akula summary years experience aro...
# 76  mooraboyina guravaiah workday integration spec...
# 77  venkateswarlu b workday consultant years exper...
# 78  madeeswar profile summary around years experie...
#
#                    category_1 category2 category3        category4  \
# 0   React JS Developer Resume       NaN       NaN              NaN
# 1   React JS Developer Resume       NaN       NaN              NaN
# 2   React JS Developer Resume       NaN       NaN              NaN
# 3   React JS Developer Resume       NaN       NaN              NaN
# 4   React JS Developer Resume       NaN       NaN              NaN
# ..                        ...       ...       ...              ...
# 74                        NaN       NaN       NaN  Workday Resumes
# 75                        NaN       NaN       NaN  Workday Resumes
# 76                        NaN       NaN       NaN  Workday Resumes
# 77                        NaN       NaN       NaN  Workday Resumes
# 78                        NaN       NaN       NaN  Workday Resumes
#
#                      Category
# 0   React JS Developer Resume
# 1   React JS Developer Resume
# 2   React JS Developer Resume
# 3   React JS Developer Resume
# 4   React JS Developer Resume
# ..                        ...
# 74            Workday Resumes
# 75            Workday Resumes
# 76            Workday Resumes
# 77            Workday Resumes
# 78            Workday Resumes
#
# [79 rows x 6 columns]

# %%
data.to_csv('RESUMES.csv',index=False)

# %%
data.Category.value_counts()
# Out:
# React JS Developer Resume          24
# Workday Resumes                    21
# Peoplesoft Resume                  20
# SQL Developer Lightning insight    14
# Name: Category, dtype: int64

# %% [markdown]
# # **Data Visualization**

# %%
Counts = data['Category'].value_counts().reset_index()['Category']
Labels  = data['Category'].value_counts().reset_index()['index']

# %%
from matplotlib.gridspec import GridSpec
plt.figure(figsize=(8,8))
plt.title('Category Distribution',fontsize=20)
source_pie = plt.pie(Counts, labels=Labels, autopct='%1.1f%%', shadow=True)
plt.show()

# %%
data['Category'].value_counts().sort_index().plot(kind='bar', figsize=(6, 4))
plt.show()

# %%
import seaborn as sns
sns.pairplot(data = data)

# %%
plt.figure(figsize=(6,6))
plt.xticks()
sns.countplot(y="Category", data=data)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
import string
from nltk.corpus import stopwords
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = data['Resumes'].values
cleanedSentences = ""
for records in Sentences:
    cleanedSentences += records
    requiredWords = nltk.word_tokenize(records)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)

wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(100)
print(mostcommon)
# Out:
# [('experience', 598), ('peoplesoft', 453), ('workday', 431), ('application', 418), ('using', 395), ('server', 360), ('data', 332), ('project', 326), ('reports', 326), ('sql', 280), ('business', 273), ('web', 250), ('database', 243), ('process', 236), ('worked', 220), ('knowledge', 216), ('client', 197), ('system', 192), ('involved', 191), ('tools', 190), ('integrations', 189), ('integration', 183), ('hcm', 182), ('like', 180), ('support', 178), ('skills', 171), ('good', 169), ('development', 168), ('team', 166), ('creating', 164), ('working', 162), ('technical', 160), ('people', 160), ('services', 157), ('report', 155), ('design', 154), ('servers', 152), ('created', 150), ('testing', 150), ('react', 148), ('various', 146), ('oracle', 143), ('role', 142), ('developer', 139), ('environment', 139), ('responsibilities', 137), ('management', 136), ('security', 134), ('eib', 134), ('production', 133), ('issues', 132), ('core', 128), ('studio', 128), ('work', 124), ('custom', 124), ('js', 123), ('windows', 118), ('applications', 116), ('date', 115), ('domains', 115), ('professional', 112), ('developed', 112), ('new', 112), ('scheduler', 111), ('requirements', 110), ('code', 109), ('e', 109), ('test', 108), ('technologies', 105), ('fields', 105), ('html', 97), ('used', 97), ('consultant', 97), ('change', 95), ('requirement', 94), ('user', 94), ('years', 93), ('fscm', 92), ('end', 91), ('systems', 91), ('software', 90), ('responsible', 90), ('based', 89), ('information', 89), ('c', 89), ('reporting', 86), ('summary', 84), ('css', 84), ('performance', 84), ('xml', 83), ('per', 83), ('r', 83), ('maintenance', 82), ('developing', 81), ('different', 81), ('g', 81), ('roles', 78), ('day', 78), ('functional', 78), ('functions', 77)]

# %%
plt.figure(figsize=(6,6))
wordcloud = WordCloud(background_color='black').generate(cleanedSentences)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
categories = np.sort(data['Category'].unique())

# %%
data_categories = [data[data['Category'] == category].loc[:, ['Resumes', 'Category']] for category in categories]
data_categories
# Out:
# [                                              Resumes           Category
#  24  peoplesoft administration vivekanand sayana ca...  Peoplesoft Resume
#  25  peoplesoft administrator srinivas k experience...  Peoplesoft Resume
#  26  hari narayana professional summary years exper...  Peoplesoft Resume
#  27  arun venu experience summary experience years ...  Peoplesoft Resume
#  28  murali professional summary years experience p...  Peoplesoft Resume
#  29  rahul ahuja summary years experience peoplesof...  Peoplesoft Resume
#  30  peoplesoft admin peoplesoft dba ganesh alladi ...  Peoplesoft Resume
#  31  peoplesoft database administrator gangareddy p...  Peoplesoft Resume
#  32  priyabrata hota career objective pursuing peop...  Peoplesoft Resume
#  33  classification internal classification interna...  Peoplesoft Resume
#  34  sirazuddin bangalore india sirazuddin bangalor...  Peoplesoft Resume
#  35  personal details name pritam biswas date birth...  Peoplesoft Resume
#  36  tanna sujatha objective seeking challenging ro...  Peoplesoft Resume
#  37  c n c address manyata tech park nagavara banga...  Peoplesoft Resume
#  38  profile summary years experience implementing ...  Peoplesoft Resume
#  39  priyanka ramadoss mountpleasant coonoor nilgir...  Peoplesoft Resume
#  40  r ahmed peoplesoft technical consultant profes...  Peoplesoft Resume
#  41  vinod akkala peoplesoft dba admin professional...  Peoplesoft Resume
#  42  peoplesoft admin varkala vikas career objectiv...  Peoplesoft Resume
#  43  anubhav kumar singh core competencies scriptin...  Peoplesoft Resume,
#                                                Resumes  \
#  0   ui developer react js developer name krishna p...
#  1   md khizaruddin rauf experience currently worki...
#  2   pragnya pattnaik expertise around years experi...
#  3   venkatalakshmi pedireddy software developer ex...
#  4   kotani durga prasad objective aspirant positio...
#  5   thirupathamma balla summary year experience re...
#  6   naveen sadhu title software developer location...
#  7   susovan bag seeking challenging position field...
#  8   curriculum vitae anjani priyadarshini objectiv...
#  9   haripriya battina experience ui developer reac...
#  10  maryala vinay reddy professional summary years...
#  11  sarala madasu sarala madasu sri geethika prest...
#  12  mareedu lokesh babu professional overview arou...
#  13  kamalakar reddy linked www linkedin com kamala...
#  14  kanumuru deepak reddy career objective secure ...
#  15  ranga gaganam professional summary professiona...
#  16  name prabakaran title ui developer professiona...
#  17  mareedu lokesh babu professional overview arou...
#  18  pranish sonone career summary experience years...
#  19  pic profile searching opportunity bring years ...
#  20  kambala sai surendra summary project basic kno...
#  21  shaik abdul sharuk years experience wipro care...
#  22  name ravali p curriculum vitae specialization ...
#  23  ui developer react js developer name krishna p...
#
#                       Category
#  0   React JS Developer Resume
#  1   React JS Developer Resume
#  2   React JS Developer Resume
#  3   React JS Developer Resume
#  4   React JS Developer Resume
#  5   React JS Developer Resume
#  6   React JS Developer Resume
#  7   React JS Developer Resume
#  8   React JS Developer Resume
#  9   React JS Developer Resume
#  10  React JS Developer Resume
#  11  React JS Developer Resume
#  12  React JS Developer Resume
#  13  React JS Developer Resume
#  14  React JS Developer Resume
#  15  React JS Developer Resume
#  16  React JS Developer Resume
#  17  React JS Developer Resume
#  18  React JS Developer Resume
#  19  React JS Developer Resume
#  20  React JS Developer Resume
#  21  React JS Developer Resume
#  22  React JS Developer Resume
#  23  React JS Developer Resume  ,
#                                                Resumes  \
#  44  sql msbi developer sql msbi developer b vinod ...
#  45  anil kumar maddukuri sql msbi developer summar...
#  46  raju pavana kumari professional summary years ...
#  47  aradhana tripathi current location gachibowli ...
#  48  name ramesh career objective contribute organi...
#  49  sql developer name bandi prem sai career objec...
#  50  resume name neeraj mishra experience summary y...
#  51  hyderabad nazeer basha sql power bi developer ...
#  52  buddha vamsi career objective years experience...
#  53  sql server developer p syam kumar professional...
#  54  kamballa pradeep synopsis looking forward aspi...
#  55  resume ramalakshmi k career objective professi...
#  56  career objective rewarding opportunity growth ...
#  57  sql server developer priyanka l professional s...
#
#                             Category
#  44  SQL Developer Lightning insight
#  45  SQL Developer Lightning insight
#  46  SQL Developer Lightning insight
#  47  SQL Developer Lightning insight
#  48  SQL Developer Lightning insight
#  49  SQL Developer Lightning insight
#  50  SQL Developer Lightning insight
#  51  SQL Developer Lightning insight
#  52  SQL Developer Lightning insight
#  53  SQL Developer Lightning insight
#  54  SQL Developer Lightning insight
#  55  SQL Developer Lightning insight
#  56  SQL Developer Lightning insight
#  57  SQL Developer Lightning insight  ,
#                                                Resumes         Category
#  58  venkata saikrishna workday consultant profssio...  Workday Resumes
#  59  jyoti verma professional summary professional ...  Workday Resumes
#  60  workday hcm fcm name kumar role workday consul...  Workday Resumes
#  61  hima mendu career objective continue growing k...  Workday Resumes
#  62  pic pic years experience workday hcm technical...  Workday Resumes
#  63  srikanth workday hcm consultant seeking suitab...  Workday Resumes
#  64  ramesh workday hcm consultant professional sum...  Workday Resumes
#  65  vinay kumar v workday functional consultant ex...  Workday Resumes
#  66  workday hcm techno functional consultant rahul...  Workday Resumes
#  67  shireesh balasani hcm consultant profile summa...  Workday Resumes
#  68  chinna subbarayudu dob th march nationality in...  Workday Resumes
#  69  hari krishna summary result oriented professio...  Workday Resumes
#  70  g himaja career objective work towards achievi...  Workday Resumes
#  71  workday integration consultant name sri krishn...  Workday Resumes
#  72  name naresh babu cherukuri objective take resp...  Workday Resumes
#  73  name gopi krishna reddy professional summery w...  Workday Resumes
#  74  pic name j sumanth royal professional summary ...  Workday Resumes
#  75  harikrishna akula summary years experience aro...  Workday Resumes
#  76  mooraboyina guravaiah workday integration spec...  Workday Resumes
#  77  venkateswarlu b workday consultant years exper...  Workday Resumes
#  78  madeeswar profile summary around years experie...  Workday Resumes]

# %%
def wordcloud(df):
    txt = ' '.join(txt for txt in data['Resumes'])
    wordcloud = WordCloud(
        height=2000,
        width=4000,
         ).generate(txt)

    return wordcloud

# %%
plt.figure(figsize=(32, 28))

for i, category in enumerate(categories):
    wc = wordcloud(data_categories[i])

    plt.subplot(5, 5, i + 1).set_title(category)
    plt.imshow(wc)
    plt.axis('off')
    plt.plot()

plt.show()
plt.close()

# %%
from sklearn.preprocessing import LabelEncoder
cat = ['Category']
for i in cat:
     data[i] = LabelEncoder().fit_transform(data[i])

# %%
le = LabelEncoder()
data['Category'] = le.fit_transform(data['Category'])

# %%
data
# Out:
#                                               Resumes  \
# 0   ui developer react js developer name krishna p...
# 1   md khizaruddin rauf experience currently worki...
# 2   pragnya pattnaik expertise around years experi...
# 3   venkatalakshmi pedireddy software developer ex...
# 4   kotani durga prasad objective aspirant positio...
# ..                                                ...
# 74  pic name j sumanth royal professional summary ...
# 75  harikrishna akula summary years experience aro...
# 76  mooraboyina guravaiah workday integration spec...
# 77  venkateswarlu b workday consultant years exper...
# 78  madeeswar profile summary around years experie...
#
#                    category_1 category2 category3        category4  Category
# 0   React JS Developer Resume       NaN       NaN              NaN         1
# 1   React JS Developer Resume       NaN       NaN              NaN         1
# 2   React JS Developer Resume       NaN       NaN              NaN         1
# 3   React JS Developer Resume       NaN       NaN              NaN         1
# 4   React JS Developer Resume       NaN       NaN              NaN         1
# ..                        ...       ...       ...              ...       ...
# 74                        NaN       NaN       NaN  Workday Resumes         3
# 75                        NaN       NaN       NaN  Workday Resumes         3
# 76                        NaN       NaN       NaN  Workday Resumes         3
# 77                        NaN       NaN       NaN  Workday Resumes         3
# 78                        NaN       NaN       NaN  Workday Resumes         3
#
# [79 rows x 6 columns]

# %%
data.Category.value_counts()
# Out:
# 1    24
# 3    21
# 0    20
# 2    14
# Name: Category, dtype: int64

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer=WordNetLemmatizer()
def lemmatize_text(text):
     a= [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]
     return ' '.join(a)

# %%
data['Resumes'] = data.Resumes.apply(lemmatize_text)

# %%
data
# Out:
#                                               Resumes  \
# 0   ui developer react j developer name krishna pr...
# 1   md khizaruddin rauf experience currently worki...
# 2   pragnya pattnaik expertise around year experie...
# 3   venkatalakshmi pedireddy software developer ex...
# 4   kotani durga prasad objective aspirant positio...
# ..                                                ...
# 74  pic name j sumanth royal professional summary ...
# 75  harikrishna akula summary year experience arou...
# 76  mooraboyina guravaiah workday integration spec...
# 77  venkateswarlu b workday consultant year experi...
# 78  madeeswar profile summary around year experien...
#
#                    category_1 category2 category3        category4  Category
# 0   React JS Developer Resume       NaN       NaN              NaN         1
# 1   React JS Developer Resume       NaN       NaN              NaN         1
# 2   React JS Developer Resume       NaN       NaN              NaN         1
# 3   React JS Developer Resume       NaN       NaN              NaN         1
# 4   React JS Developer Resume       NaN       NaN              NaN         1
# ..                        ...       ...       ...              ...       ...
# 74                        NaN       NaN       NaN  Workday Resumes         3
# 75                        NaN       NaN       NaN  Workday Resumes         3
# 76                        NaN       NaN       NaN  Workday Resumes         3
# 77                        NaN       NaN       NaN  Workday Resumes         3
# 78                        NaN       NaN       NaN  Workday Resumes         3
#
# [79 rows x 6 columns]
